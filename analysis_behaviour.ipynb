# %%
import numpy as np
import tifffile as tf
import ntpath
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import sys
import time
import math
from paq2py import *
from utils_funcs import *
import seaborn as sns
from random import randint
from scipy import stats
import csv
import pickle 
import scipy.io

# %matplotlib notebook

# %% [markdown]
# # Load data from the steering wheel task

# %%
response_times = scipy.io.loadmat('D:/PackerStation-backup/IBL_Task_Data/subjects/subject_D006/2019-07-25/1/RT_2019-07-25_DO006.mat')

response_times = response_times['RT']
response_times = np.squeeze(response_times)

# %%
img_1 = mpimg.imread('D:/IBL-schematic.png')
img_2 = mpimg.imread('D:/IBL-example.png')
img_3 = mpimg.imread('D:/IBL-task.png')

# %% [markdown]
# # Extract performance data from the matlab script

# %% [markdown]
# <font color='blue'>Here data was entered by hand but in the future a script should be written to transport automatically data from matlab to Jupyter

# %%
perf= np.array([[42.7,54.3,52.1,56.4,47.6,55.3,50.6,50.5,47.48,50.4,56.13,54.27,51.2,47.12,57.7,54.55,52.8,58.7,55.1,57.6,51.8,64.1,62.61,62.3,62.7,70.3,82.2,84.3,82.8,76.3,83.61,86.25,89.66,80.84,79.43,92.75,81.5,74.18,82.92,78.3,73.84,69.28,78.61,71.56,79.27,82.22,87.4,69.88,83.69,81.1,77.78,79.51],
               [60.83,50,55.3,50.5,49.1,50.9,54,55.2,50.11,51.5,49.7,52.7,61.2,50.45,39.66,59.43,54.13,48.06,53.8,55,54.35,61.1,54,53.7,49.7,53.9,47,48.1,49.5,46.9,43,48.4,41.6,41.7,47.3,43.1,52.6,51.4,53.1,50.9,48.4,50.1],
               [50.34,53.19,53.47,47.92,55.48,56.73,61.1,52.8,46.46,56.4,51.1,67.05,57.8,51.7,61.1,59.2,43.6,50.9,41.2,56.7,59.89,57.7,53,51.66,50.43,57.38]])

# %% [markdown]
# <font color='blue'>Plot

# %%
plt.figure()

plt.subplot(2,2,1)

x_axis = (np.arange(len(perf[0])))
#[plt.plot(x_axis, t, c='grey', alpha=0.2) for t in perf]
plt.plot(x_axis, perf[0], c='green', alpha=0.6)

x_axis = (np.arange(len(perf[1])))
plt.plot(x_axis, perf[1], c='grey', alpha=0.2)

x_axis = (np.arange(len(perf[2])))
plt.plot(x_axis, perf[2], c='grey', alpha=0.2)

#plt.plot(x_axis, np.mean(perf))

plt.ylim([30,100])
plt.xlabel('Day')
plt.ylabel('Performance (%)')

plt.subplot(2,2,2)

plt.hist(response_times, bins=20)
plt.xlabel('Time (s)')
plt.ylabel('Number of trials')

sns.despine()
plt.tight_layout()
plt.show()
plt.savefig("behaviour.TIFF")
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %% [markdown]
# <font color='blue'>Make figure

# %%
plt.figure()

plt.subplot(221)
plt.imshow(img_1,interpolation='kaiser')
plt.axis('off')

plt.subplot(222)
plt.imshow(img_2,interpolation='kaiser')
plt.axis('off')

plt.subplot(212)
plt.imshow(img_3)
plt.axis('off')

sns.despine()
plt.tight_layout()
plt.show()

plt.savefig("foo2.pdf")
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
